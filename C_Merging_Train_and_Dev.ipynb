# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import json
import pandas as pd
def read_jsonl_to_df(file_path):
    with open(file_path, 'r', encoding='utf-8') as file:
        data = [json.loads(line) for line in file]
    return pd.DataFrame(data)
file_path1 = '/content/drive/MyDrive/SemEval 2024/subtaskC_train.jsonl'
file_path2 = '/content/drive/MyDrive/SemEval 2024/subtaskC_dev.jsonl'

# %%
df1 = read_jsonl_to_df(file_path1)
print("DataFrame 1:")
df1
# Out:
# DataFrame 1:
#                                         id  \
# 0     5df7a120-f5ff-4881-8624-058f8a2fee5a
# 1     063f9429-b94b-4e86-bd4c-c48e9bf85850
# 2     2759de87-3708-4f81-9e5f-ed132c292d2f
# 3     25ef7554-db90-4212-b218-06679b25efb8
# 4     8b51f390-6552-4982-b5d4-1b165e598df1
# ...                                    ...
# 3644  35a52bbb-c5d8-4446-8e5c-b4521d895196
# 3645  e8941b7e-e562-4c91-b051-678d0b4a885a
# 3646  1faa5671-0ec6-4b9a-b539-c7381d09b518
# 3647  e0078728-7e68-467b-b843-0572211ad812
# 3648  436fa3e9-e2cf-4ac9-b750-cd5e5402a1a8
#
#                                                    text  label
# 0     - Strengths:\r\n* Outperforms ALIGN in supervi...     88
# 1     This paper addresses the problem of disambigua...    286
# 2     - Strengths:\r\nGood ideas, simple neural lear...     62
# 3     This paper presents several weakly supervised ...     35
# 4     This paper describes a model for cross-lingual...     98
# ...

# %%
df2 = read_jsonl_to_df(file_path2)
print("\nDataFrame 2:")
df2
# Out:
# DataFrame 2:
#                                        id  \
# 0    085e6abb-48c7-4388-9d70-901c4b173369
# 1    f8f8e2cb-494d-4a67-be25-d10e07f2c622
# 2    2dbf1cd7-ae9d-4f43-8e07-d981e1b97c14
# 3    4de9ac55-2090-4da6-9431-40137992d68b
# 4    a4a87fad-acac-4b54-bc6d-9ca998ccf34e
# ..                                    ...
# 500  cc47f967-cdb8-42f4-b46f-334e02bc81c1
# 501  0d03f81c-f27c-4945-acd2-ad185fbe0e6e
# 502  6091a95d-0643-4db3-96be-8252f042926e
# 503  913d7859-2b5a-4dae-bc57-b2895dde8f1a
# 504  b3ae3144-22d5-464e-9ea4-72eaa1adb2f9
#
#                                                   text  label
# 0    The paper describes an extension of word embed...     94
# 1    Summary: This paper presents a model for embed...     86
# 2    The authors presents a method to jointly embed...    403
# 3    Dear Authors\r\n\r\nthanks for replying to our...     12
# 4    - Strengths:\r\n\r\n1) This paper proposed a s...     75
# ..                                                 ...    ...
# ...

# %%
df_merged = pd.concat([df1, df2], ignore_index=True)
print("\nMerged DataFrame:")
df_merged
# Out:
# Merged DataFrame:
#                                         id  \
# 0     5df7a120-f5ff-4881-8624-058f8a2fee5a
# 1     063f9429-b94b-4e86-bd4c-c48e9bf85850
# 2     2759de87-3708-4f81-9e5f-ed132c292d2f
# 3     25ef7554-db90-4212-b218-06679b25efb8
# 4     8b51f390-6552-4982-b5d4-1b165e598df1
# ...                                    ...
# 4149  cc47f967-cdb8-42f4-b46f-334e02bc81c1
# 4150  0d03f81c-f27c-4945-acd2-ad185fbe0e6e
# 4151  6091a95d-0643-4db3-96be-8252f042926e
# 4152  913d7859-2b5a-4dae-bc57-b2895dde8f1a
# 4153  b3ae3144-22d5-464e-9ea4-72eaa1adb2f9
#
#                                                    text  label
# 0     - Strengths:\r\n* Outperforms ALIGN in supervi...     88
# 1     This paper addresses the problem of disambigua...    286
# 2     - Strengths:\r\nGood ideas, simple neural lear...     62
# 3     This paper presents several weakly supervised ...     35
# 4     This paper describes a model for cross-lingual...     98
# ...

# %%
output_file = 'SubtaskC_TrainAll.jsonl'
df_merged.to_json(output_file, orient='records', lines=True)

# %%
# !mv /content/SubtaskC_TrainAll.jsonl /content/drive/MyDrive/SemEval\ 2024/
